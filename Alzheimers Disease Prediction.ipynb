# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("alzheimers_disease_data.csv")

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# PatientID                    0.0
# Age                          0.0
# Gender                       0.0
# Ethnicity                    0.0
# EducationLevel               0.0
# BMI                          0.0
# Smoking                      0.0
# AlcoholConsumption           0.0
# PhysicalActivity             0.0
# DietQuality                  0.0
# SleepQuality                 0.0
# FamilyHistoryAlzheimers      0.0
# CardiovascularDisease        0.0
# Diabetes                     0.0
# Depression                   0.0
# HeadInjury                   0.0
# Hypertension                 0.0
# SystolicBP                   0.0
# DiastolicBP                  0.0
# CholesterolTotal             0.0
# CholesterolLDL               0.0
# CholesterolHDL               0.0
# CholesterolTriglycerides     0.0
# MMSE                         0.0
# FunctionalAssessment         0.0
# MemoryComplaints             0.0
# BehavioralProblems           0.0
# ADL                          0.0
# ...

# %%
df.drop(["PatientID", "DoctorInCharge"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0   73       0          0               2  22.927749        0
# 1   89       0          0               0  26.827681        0
# 2   73       0          3               1  17.795882        0
# 3   74       1          0               1  33.800817        1
# 4   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  ...  \
# 0           13.297218          6.327112     1.347214      9.025679  ...
# 1            4.542524          7.619885     0.518767      7.151293  ...
# 2           19.555085          7.844988     1.826335      9.673574  ...
# 3           12.209266          8.428001     7.435604      8.392554  ...
# 4           18.454356          6.310461     0.795498      5.597238  ...
#
#    FunctionalAssessment  MemoryComplaints  BehavioralProblems       ADL  \
# 0              6.518877                 0                   0  1.725883
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        2149 non-null   int64
#  1   Gender                     2149 non-null   int64
#  2   Ethnicity                  2149 non-null   int64
#  3   EducationLevel             2149 non-null   int64
#  4   BMI                        2149 non-null   float64
#  5   Smoking                    2149 non-null   int64
#  6   AlcoholConsumption         2149 non-null   float64
#  7   PhysicalActivity           2149 non-null   float64
#  8   DietQuality                2149 non-null   float64
#  9   SleepQuality               2149 non-null   float64
#  10  FamilyHistoryAlzheimers    2149 non-null   int64
#  11  CardiovascularDisease      2149 non-null   int64
#  12  Diabetes                   2149 non-null   int64
# ...

# %%
for i in df.columns:
    print(i)
    print(df[i].isnull().sum())
    sns.boxplot(df[i])
    plt.show()
# Out:
# Age
# 0
# Gender
# 0
# Ethnicity
# 0
# EducationLevel
# 0
# BMI
# 0
# Smoking
# 0
# AlcoholConsumption
# 0
# PhysicalActivity
# 0
# DietQuality
# 0
# SleepQuality
# 0
# FamilyHistoryAlzheimers
# 0
# CardiovascularDisease
# 0
# Diabetes
# 0
# Depression
# 0
# HeadInjury
# 0
# Hypertension
# 0
# SystolicBP
# 0
# DiastolicBP
# 0
# CholesterolTotal
# 0
# CholesterolLDL
# 0
# CholesterolHDL
# 0
# CholesterolTriglycerides
# 0
# MMSE
# 0
# FunctionalAssessment
# 0
# MemoryComplaints
# 0
# BehavioralProblems
# 0
# ADL
# 0
# Confusion
# 0
# Disorientation
# 0
# PersonalityChanges
# 0
# DifficultyCompletingTasks
# 0
# Forgetfulness
# 0
# Diagnosis
# 0

# %%
x = df.drop("Diagnosis", axis  = 1)
y = df[["Diagnosis"]]

# %%
sns.heatmap(x.corr())
# Out:
# <Axes: >

# %%
X = x.values
Y = y.values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)
print(x_train.shape)
print(y_train.shape)
# Out:
# (1719, 32)
# (1719, 1)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# C:\Users\Ajinkya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Ajinkya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

# %%
def model_performance(actual, predicted):
    print("Accuracy Score: ", accuracy_score(actual, predicted))
    print("Confusion Matrix: ")
    print(confusion_matrix(actual, predicted))
    print("Classification Report: ")
    print(classification_report(actual, predicted))
    print("Roc_auc_score :", roc_auc_score(actual, predicted))

# %%
model_performance(y_pred, y_train)
# Out:
# Accuracy Score:  0.8027923211169284
# Confusion Matrix:
# [[999 216]
#  [123 381]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      1215
#            1       0.64      0.76      0.69       504
#
#     accuracy                           0.80      1719
#    macro avg       0.76      0.79      0.77      1719
# weighted avg       0.82      0.80      0.81      1719
#
# Roc_auc_score : 0.7890873015873014

# %%
y_test_pred = lr.predict(x_test)

# %%
model_performance(y_test_pred, y_test)
# Out:
# Accuracy Score:  0.7953488372093023
# Confusion Matrix:
# [[240  61]
#  [ 27 102]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85       301
#            1       0.63      0.79      0.70       129
#
#     accuracy                           0.80       430
#    macro avg       0.76      0.79      0.77       430
# weighted avg       0.82      0.80      0.80       430
#
# Roc_auc_score : 0.7940199335548173

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
y_train_pred = dtree.predict(x_train)
model_performance(y_train_pred, y_train)
# Out:
# Accuracy Score:  1.0
# Confusion Matrix:
# [[1122    0]
#  [   0  597]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1122
#            1       1.00      1.00      1.00       597
#
#     accuracy                           1.00      1719
#    macro avg       1.00      1.00      1.00      1719
# weighted avg       1.00      1.00      1.00      1719
#
# Roc_auc_score : 1.0

# %%
y_test_pred = dtree.predict(x_test)
model_performance(y_test_pred, y_test)
# Out:
# Accuracy Score:  0.9232558139534883
# Confusion Matrix:
# [[248  14]
#  [ 19 149]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       262
#            1       0.91      0.89      0.90       168
#
#     accuracy                           0.92       430
#    macro avg       0.92      0.92      0.92       430
# weighted avg       0.92      0.92      0.92       430
#
# Roc_auc_score : 0.9167348237004725

# %%
import gradio as gr

# %%
for i in x.columns:
    print(i, "minimum=",x[i].min(), "maximum=", x[i].max())
# Out:
# Age minimum= 60 maximum= 90
# Gender minimum= 0 maximum= 1
# Ethnicity minimum= 0 maximum= 3
# EducationLevel minimum= 0 maximum= 3
# BMI minimum= 15.00885118163106 maximum= 39.99276746402374
# Smoking minimum= 0 maximum= 1
# AlcoholConsumption minimum= 0.0020030991362718 maximum= 19.98929335906197
# PhysicalActivity minimum= 0.003616016826019 maximum= 9.987429413422252
# DietQuality minimum= 0.00938472011623 maximum= 9.99834567881401
# SleepQuality minimum= 4.002628659826611 maximum= 9.99984031668144
# FamilyHistoryAlzheimers minimum= 0 maximum= 1
# CardiovascularDisease minimum= 0 maximum= 1
# Diabetes minimum= 0 maximum= 1
# Depression minimum= 0 maximum= 1
# HeadInjury minimum= 0 maximum= 1
# Hypertension minimum= 0 maximum= 1
# SystolicBP minimum= 90 maximum= 179
# DiastolicBP minimum= 60 maximum= 119
# CholesterolTotal minimum= 150.09331559406317 maximum= 299.99335247432657
# CholesterolLDL minimum= 50.23070655980742 maximum= 199.96566510142804
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI', 'Smoking',
#        'AlcoholConsumption', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryAlzheimers', 'CardiovascularDisease', 'Diabetes',
#        'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP', 'DiastolicBP',
#        'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis'],
#       dtype='object')

# %%
import gradio as gr
import numpy as np

# Define the prediction function
def predict_binary_classification(Age, Gender, Ethnicity, EducationLevel, BMI, Smoking, AlcoholConsumption, PhysicalActivity, DietQuality, 
                                  SleepQuality, FamilyHistoryAlzheimers, CardiovascularDisease, Diabetes, Depression, HeadInjury, Hypertension, 
                                  SystolicBP, DiastolicBP, CholesterolTotal, CholesterolLDL, CholesterolHDL, CholesterolTriglycerides, MMSE, 
                                  FunctionalAssessment, MemoryComplaints, BehavioralProblems, ADL, Confusion, Disorientation, PersonalityChanges, 
                                  DifficultyCompletingTasks, Forgetfulness):
    input_data = np.array([Age, Gender, Ethnicity, EducationLevel, BMI, Smoking, AlcoholConsumption, PhysicalActivity, DietQuality, 
                                  SleepQuality, FamilyHistoryAlzheimers, CardiovascularDisease, Diabetes, Depression, HeadInjury, Hypertension, 
                                  SystolicBP, DiastolicBP, CholesterolTotal, CholesterolLDL, CholesterolHDL, CholesterolTriglycerides, MMSE, 
                                  FunctionalAssessment, MemoryComplaints, BehavioralProblems, ADL, Confusion, Disorientation, PersonalityChanges, 
                                  DifficultyCompletingTasks, Forgetfulness]).reshape(1, -1)
    prediction = dtree.predict(input_data)
    return "Positive" if prediction[0] == 1 else "Negative"

# Create a Gradio interface with sliders
interface = gr.Interface(
    fn=predict_binary_classification, 
    inputs=[
        gr.Slider(label="Age", minimum=60, maximum=90, step=1),
        gr.Slider(label="Gender", minimum=0, maximum=1, step=1),
        gr.Slider(label="Ethnicity", minimum=0, maximum=3, step=1),
        gr.Slider(label="EducationLevel", minimum=0, maximum=3, step=1),
        gr.Slider(label="BMI", minimum=15.00885118163106, maximum=39.99276746402374, step=1.0),
        gr.Slider(label="Smoking", minimum=0, maximum=1, step=1),
        gr.Slider(label="AlcoholConsumption", minimum=0.0020030991362718, maximum=19.98929335906197, step=1.0),
        gr.Slider(label="PhysicalActivity", minimum=0.003616016826019, maximum=9.987429413422252, step=1.0),
        gr.Slider(label="DietQuality", minimum=0.00938472011623, maximum=9.99834567881401, step=1.0),
        gr.Slider(label="SleepQuality", minimum=4.002628659826611, maximum=9.99984031668144, step=1.0),
        gr.Slider(label="FamilyHistoryAlzheimers", minimum=0, maximum=1, step=1),
        gr.Slider(label="CardiovascularDisease", minimum=0, maximum=1, step=1),
        gr.Slider(label="Diabetes", minimum=0, maximum=1, step=1),
        gr.Slider(label="Depression", minimum=0, maximum=1, step=1),
        gr.Slider(label="HeadInjury", minimum=0, maximum=1, step=1),
        gr.Slider(label="Hypertension", minimum=0, maximum=1, step=1),
        gr.Slider(label="SystolicBP", minimum=90, maximum=179, step=1),
        gr.Slider(label="DiastolicBP", minimum=60, maximum=119, step=1),
        gr.Slider(label="CholesterolTotal", minimum=150.09331559406317, maximum=299.99335247432657, step=1.0),
        gr.Slider(label="CholesterolLDL", minimum=50.23070655980742, maximum=199.96566510142804, step=1.0),
        gr.Slider(label="CholesterolHDL", minimum=20.00343401498445, maximum=99.98032407804152, step=1.0),
        gr.Slider(label="CholesterolTriglycerides", minimum=50.40719361978579, maximum=399.9418615941332, step=1.0),
        gr.Slider(label="MMSE", minimum=0.0053121464417005, maximum=29.991380560529063, step=1.0),
        gr.Slider(label="FunctionalAssessment", minimum=0.000459593595804, maximum=9.996467072555015, step=1.0),
        gr.Slider(label="MemoryComplaints", minimum=0, maximum=1, step=1),
        gr.Slider(label="BehavioralProblems", minimum=0, maximum=1, step=1),
        gr.Slider(label="ADL", minimum=0.0012879277024868, maximum=9.99974712180168, step=1.0),
        gr.Slider(label="Confusion", minimum=0, maximum=1, step=1),
        gr.Slider(label="Disorientation", minimum=0, maximum=1, step=1),
        gr.Slider(label="PersonalityChanges", minimum=0, maximum=1, step=1),
        gr.Slider(label="DifficultyCompletingTasks", minimum=0, maximum=1, step=1),
        gr.Slider(label="Forgetfulness", minimum=0, maximum=1, step=1)
    ], 
    outputs="text",
    title="Alzheimer's Diagnosis with Decision Tree",
    description="Use the sliders to enter values within the specified ranges for each feature to predict whether the patient has 'Alzheimer' or 'not."
)

# Launch the Gradio interface
interface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://3c0abbc9ce2c0b7bd2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3c0abbc9ce2c0b7bd2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
